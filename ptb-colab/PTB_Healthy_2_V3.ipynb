# %% [markdown]
# <a href="https://colab.research.google.com/github/potatosoupx/python/blob/main/ptb-colab/PTB_Healthy_2_V3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install wfdb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 33.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# ...

# %%
import wfdb
import scipy.signal as signal
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
Data1= {
    1:
    pd.read_csv('/content/drive/MyDrive/Healthy/104/s0306lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    2:
    pd.read_csv('/content/drive/MyDrive/Healthy/105/s0303lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    3:
    pd.read_csv('/content/drive/MyDrive/Healthy/116/s0302lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    4:
    pd.read_csv('/content/drive/MyDrive/Healthy/117/s0292lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    5:
    pd.read_csv('/content/drive/MyDrive/Healthy/121/s0311lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    6:
    pd.read_csv('/content/drive/MyDrive/Healthy/122/s0312lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    7:
    pd.read_csv('/content/drive/MyDrive/Healthy/131/s0273lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    8:
    pd.read_csv('/content/drive/MyDrive/Healthy/150/s0287lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    9:
    pd.read_csv('/content/drive/MyDrive/Healthy/155/s0301lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    10:
    pd.read_csv('/content/drive/MyDrive/Healthy/156/s0299lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    11:
    pd.read_csv('/content/drive/MyDrive/Healthy/165/s0323lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    12:
    pd.read_csv('/content/drive/MyDrive/Healthy/166/s0275lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    13:
    pd.read_csv('/content/drive/MyDrive/Healthy/169/s0329lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[9000:12000,:],
    14:
    pd.read_csv('/content/drive/MyDrive/Healthy/170/s0274lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    15:
    pd.read_csv('/content/drive/MyDrive/Healthy/172/s0304lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    16:
    pd.read_csv('/content/drive/MyDrive/Healthy/173/s0305lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    17:
    pd.read_csv('/content/drive/MyDrive/Healthy/174/s0300lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    18:
    pd.read_csv('/content/drive/MyDrive/Healthy/180/s0475_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    19:
    pd.read_csv('/content/drive/MyDrive/Healthy/182/s0308lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    20:
    pd.read_csv('/content/drive/MyDrive/Healthy/184/s0363lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    21:
    pd.read_csv('/content/drive/MyDrive/Healthy/185/s0336lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[16000:19000,:],
    22:
    pd.read_csv('/content/drive/MyDrive/Healthy/198/s0415lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    23:
    pd.read_csv('/content/drive/MyDrive/Healthy/214/s0436_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    24:
    pd.read_csv('/content/drive/MyDrive/Healthy/229/s0452_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    25:
    pd.read_csv('/content/drive/MyDrive/Healthy/233/s0483_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    26:
    pd.read_csv('/content/drive/MyDrive/Healthy/234/s0460_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    27:
    pd.read_csv('/content/drive/MyDrive/Healthy/235/s0461_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    28:
    pd.read_csv('/content/drive/MyDrive/Healthy/236/s0463_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    29:
    pd.read_csv('/content/drive/MyDrive/Healthy/237/s0465_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    30:
    pd.read_csv('/content/drive/MyDrive/Healthy/238/s0466_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    31:
    pd.read_csv('/content/drive/MyDrive/Healthy/239/s0467_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    32:
    pd.read_csv('/content/drive/MyDrive/Healthy/240/s0468_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[2000:5000,:],
    33:
    pd.read_csv('/content/drive/MyDrive/Healthy/241/s0469_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    34:
    pd.read_csv('/content/drive/MyDrive/Healthy/242/s0471_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[2000:5000,:],
    35:
    pd.read_csv('/content/drive/MyDrive/Healthy/243/s0472_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    36:
    pd.read_csv('/content/drive/MyDrive/Healthy/244/s0473_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    37:
    pd.read_csv('/content/drive/MyDrive/Healthy/245/s0480_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    38:
    pd.read_csv('/content/drive/MyDrive/Healthy/246/s0478_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[11000:14000,:],
    39:
    pd.read_csv('/content/drive/MyDrive/Healthy/247/s0479_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    40:
    pd.read_csv('/content/drive/MyDrive/Healthy/248/s0481_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[5000:8000,:],
    41:
    pd.read_csv('/content/drive/MyDrive/Healthy/251/s0503_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    42:
    pd.read_csv('/content/drive/MyDrive/Healthy/252/s0487_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[26000:29000,:],
    43:
    pd.read_csv('/content/drive/MyDrive/Healthy/255/s0491_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[4000:7000,:],
    44:
    pd.read_csv('/content/drive/MyDrive/Healthy/260/s0496_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    45:
    pd.read_csv('/content/drive/MyDrive/Healthy/263/s0499_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    46:
    pd.read_csv('/content/drive/MyDrive/Healthy/264/s0500_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    47:
    pd.read_csv('/content/drive/MyDrive/Healthy/266/s0502_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    48:
    pd.read_csv('/content/drive/MyDrive/Healthy/267/s0504_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    49:
    pd.read_csv('/content/drive/MyDrive/Healthy/276/s0526_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[4000:7000,:],
    50:
    pd.read_csv('/content/drive/MyDrive/Healthy/277/s0527_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    51:
    pd.read_csv('/content/drive/MyDrive/Healthy/279/s0531_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:],
    52:
    pd.read_csv('/content/drive/MyDrive/Healthy/284/s0552_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[1000:4000,:]}

# %%
data1={}

def data1_set():
  for i in range (1,53):
    data1[i]= pd.DataFrame(Data1[i],columns = ['vx','vy','vz'], dtype = float).reset_index(drop=True)

data1_set()

# %%
filter1={}

def HP_filter1():
  sos1 = signal.butter(2, 0.1, 'high', fs=1000, output='sos')
  for a in range(1,53):
    filter1[a]= pd.DataFrame(signal.sosfilt(sos1, data1[a]),columns = ['vx','vy','vz'], dtype = float)

HP_filter1()

# %%
Data1[9].iloc[56:1056,:].to_csv('cut_155.csv', index=False)

# %%
Data1[8].iloc[715:1715,:].to_csv('cut_150.csv', index=False)

# %%
Data1[46].iloc[937:1937,:].to_csv('cut_264.csv', index=False)

# %%
Data1[1].iloc[1202:2202,:].to_csv('cut_104.csv', index=False)

# %%
Data1[17].iloc[862:1862,:].to_csv('cut_174.csv', index=False)

# %%
Data1[28].iloc[1827:2827,:].to_csv('cut_236.csv', index=False)

# %%
plt.plot(filter1[5]) #vx,vy,vz의 피크 지점 동일

# %%
plt.plot(filter1[47]['vx'])

# %% [markdown]
# # QRS Peak Detection

# %%
ecg_signal = np.array(filter1[1]['vx']) # 'ECG' 열의 데이터를 가져옴 하나만 측정
fs = 1000  # 샘플 레이트

# %%
from wfdb import processing
# XQRS 객체 생성 및 QRS 탐지
def detect():
  ecg_signal = {}
  for i in range (1,53):
    ecg_signal[i] = np.array(filter1[i]['vx'])
    xqrs = processing.XQRS(sig=ecg_signal[i], fs=fs)
    xqrs.detect()
    print("QRS 피크 위치:",[i],xqrs.qrs_inds)

detect()
# Out:
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [1] [ 792 1702 2615]
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [2] []
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [3] [1150 2119]
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [4] [ 666 1533 2449]
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# ...

# %%
import matplotlib.pyplot as plt

# ECG 신호 리스트와 XQRS 객체 리스트
ecg_signals = [ecg_signal1, ecg_signal2, ecg_signal3]
xqrs_objects = [xqrs1, xqrs2, xqrs3]

# 서브플롯 생성
num_signals = len(ecg_signals)  # 신호 개수
plt.figure(figsize=(12, 4 * num_signals))  # 그래프 크기 설정

for i, (ecg_signal, xqrs) in enumerate(zip(ecg_signals, xqrs_objects)):
    # 각 신호에 대해 subplot 생성
    plt.subplot(num_signals, 1, i + 1)  # (전체 행, 전체 열, 현재 위치)
    plt.plot(ecg_signal, label=f'ECG Signal {i + 1}')  # ECG 신호
    plt.plot(xqrs.qrs_inds, ecg_signal[xqrs.qrs_inds], 'ro', label='QRS Peaks')  # QRS 피크
    plt.title(f'ECG Signal {i + 1} with QRS Peaks')
    plt.xlabel('Sample Index')
    plt.ylabel('Amplitude')
    plt.legend()  # 범례 추가
    plt.grid(True)  # 격자 추가

# 그래프 간 간격 조정
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-12452791d551> in <cell line: 0>()
#      13     plt.subplot(num_signals, 1, i + 1)  # (전체 행, 전체 열, 현재 위치)
#      14     plt.plot(ecg_signal, label=f'ECG Signal {i + 1}')  # ECG 신호
# ---> 15     plt.plot(xqrs.qrs_inds, ecg_signal[xqrs.qrs_inds], 'ro', label='QRS Peaks')  # QRS 피크
#      16     plt.title(f'ECG Signal {i + 1} with QRS Peaks')
#      17     plt.xlabel('Sample Index')
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
D1={
    1:filter1[1].iloc[1202:2202,:].reset_index(drop=True),
    2:filter1[3].iloc[650:1650,:].reset_index(drop=True),
    3:filter1[4].iloc[1033:2033,:].reset_index(drop=True),
    4:filter1[5].iloc[665:1665,:].reset_index(drop=True),
    5:filter1[6].iloc[1153:2153,:].reset_index(drop=True),
    6:filter1[7].iloc[1121:2121,:].reset_index(drop=True),
    7:filter1[8].iloc[715:1715,:].reset_index(drop=True),
    8:filter1[9].iloc[825:1825,:].reset_index(drop=True),
    9:filter1[11].iloc[1406:2406,:].reset_index(drop=True),
    10:filter1[12].iloc[1190:2190,:].reset_index(drop=True),
    11:filter1[14].iloc[1221:2221,:].reset_index(drop=True),
    12:filter1[15].iloc[1002:2002,:].reset_index(drop=True),
    13:filter1[17].iloc[862:1862,:].reset_index(drop=True),
    14:filter1[19].iloc[619:1619,:].reset_index(drop=True),
    15:filter1[25].iloc[1174:2174,:].reset_index(drop=True),
    16:filter1[27].iloc[964:1964,:].reset_index(drop=True),
    17:filter1[28].iloc[878:1878,:].reset_index(drop=True),
    18:filter1[29].iloc[728:1728,:].reset_index(drop=True),
    19:filter1[30].iloc[1587:2587,:].reset_index(drop=True),
    20:filter1[36].iloc[790:1790,:].reset_index(drop=True),
    21:filter1[37].iloc[1114:2114,:].reset_index(drop=True),
    22:filter1[38].iloc[896:1896,:].reset_index(drop=True),
    23:filter1[39].iloc[756:1756,:].reset_index(drop=True),
    24:filter1[40].iloc[1087:2087,:].reset_index(drop=True),
    25:filter1[42].iloc[1289:2289,:].reset_index(drop=True),
    26:filter1[46].iloc[937:1937,:].reset_index(drop=True),
    27:filter1[48].iloc[1225:2225,:].reset_index(drop=True),
    28:filter1[49].iloc[1248:2248,:].reset_index(drop=True),
    29:filter1[50].iloc[958:1958,:].reset_index(drop=True),
    30:filter1[51].iloc[842:1842,:].reset_index(drop=True),
    31:filter1[52].iloc[925:1925,:].reset_index(drop=True)
}

# %% [markdown]
# # Offset 제거

# %%
import matplotlib.pyplot as plt

# PR Segment 평균 범위 설정 확인
x = range(len(D1[1]))
plt.figure(figsize=(18, 6))

plt.plot(x, D1[1])
plt.xticks(range(0, len(D1[1]), 20))
plt.show() # 420~460으로 설정

# %%
# 예제 ECG 신호 (사용자의 데이터로 대체 가능)
# Healthy ECG[vx] 데이터와 Average ECG[vx]를 가정
ecg_signal= D1[3]['vx']  # 예제 신호
average_ecg = np.mean(ecg_signal)  # 평균 신호로 대체 가능

# PR segment
pr_start = 420
pr_end = 460

# PR segment mean
pr_segment_mean = np.mean(ecg_signal[pr_start:pr_end])

# Raw - Mean (DC/ Offset 제거)
corrected_signal = ecg_signal - pr_segment_mean

# 결과 시각화
plt.figure(figsize=(10, 6))
plt.plot(ecg_signal, label="Original ECG", alpha=0.7)
plt.plot(corrected_signal, label="PR Segment Corrected ECG", alpha=0.7)
plt.axvspan(pr_start, pr_end, color='yellow', alpha=0.3, label="PR Segment")
plt.title("PR Segment Correction")
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
Set={} #D1 데이터 전부 Offset 제거
for i in range(1,32):
  vcg_signal_vx = D1[i]['vx']
  vcg_average_vx = np.mean(vcg_signal_vx)
  vcg_signal_vy = D1[i]['vy']
  vcg_average_vy = np.mean(vcg_signal_vy)
  vcg_signal_vz = D1[i]['vz']
  vcg_average_vz = np.mean(vcg_signal_vz)
  pr_start = 420
  pr_end = 460
  pr_segment_mean_vx = np.mean(vcg_signal_vx[pr_start:pr_end])
  pr_segment_mean_vy = np.mean(vcg_signal_vy[pr_start:pr_end])
  pr_segment_mean_vz = np.mean(vcg_signal_vz[pr_start:pr_end])
  vx_ = vcg_signal_vx - pr_segment_mean_vx
  vy_ =vcg_signal_vy - pr_segment_mean_vy
  vz_ = vcg_signal_vz - pr_segment_mean_vz

  Set[i] = pd.DataFrame({
        'vx': vx_,
        'vy': vy_,
        'vz': vz_
    })

# %% [markdown]
# # Average VCG

# %%
# 결과를 저장할 빈 DataFrame 생성
result1 = pd.DataFrame(columns=['vx_sum', 'vy_sum', 'vz_sum'])

# 0부터 1000번째 행까지 반복
for i in range(1000):
    # 각 i번째 행에서 vx, vy, vz 값을 합산
    vx_sum = sum(Set[key].iloc[i]['vx'] for key in Set.keys())
    vx_sum=vx_sum/31
    vy_sum = sum(Set[key].iloc[i]['vy'] for key in Set.keys())
    vy_sum=vy_sum/31
    vz_sum = sum(Set[key].iloc[i]['vz'] for key in Set.keys())
    vz_sum=vz_sum/31

    # 결과를 DataFrame의 새로운 행으로 추가
    result1.loc[i] = [vx_sum, vy_sum, vz_sum]
    vx_sum=0
    vy_sum=0
    vz_sum=0


# 결과 확인 (예: 첫 번째 5개의 결과 출력)
print(result1.head())
# Out:
#      vx_sum    vy_sum    vz_sum
# 0  0.073560  0.041720 -0.032149
# 1  0.072915  0.042495 -0.031826
# 2  0.072125  0.042415 -0.031439
# 3  0.071770  0.041286 -0.031147
# 4  0.071528  0.042480 -0.030761

# %%
result1.to_csv('result.csv', index=False)

# %%
import plotly.graph_objects as go
import numpy as np

# Helix equation
t = np.linspace(0, 20, 100)
fig = go.Figure(data=[go.Scatter3d(
    x=result1['vx_sum'],
    y=result1['vy_sum'],
    z=result1['vz_sum'],
    mode='markers',
    marker=dict(
        size=5,
        opacity=0.8
    )
)])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 시간 데이터 생성 (0부터 len(x)-1까지)
time = np.arange(len(x))
x = result1['vx_sum']
y = result1['vy_sum']
z = result1['vz_sum']
# 궤적에 컬러맵 적용
points = ax.scatter(x, y, z, c=time, cmap='viridis', marker='o')  # 'viridis' 컬러맵 사용
fig.colorbar(points, ax=ax, label='Time')  # 컬러바 추가

# 축 레이블 설정
ax.set_xlabel('X-axis (vx_sum)')
ax.set_ylabel('Y-axis (vy_sum)')
ax.set_zlabel('Z-axis (vz_sum)')

# 제목 추가
plt.title('3D VCG Geometry with Time')
plt.show()

# %%
# 벡터 방향 시각화
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 각 점에서 벡터를 화살표로 그리기
for i in range(1, len(x)):
    ax.quiver(x.iloc[i-1], y.iloc[i-1], z.iloc[i-1],
              x.iloc[i] - x.iloc[i-1],
              y.iloc[i] - y.iloc[i-1],
              z.iloc[i] - z.iloc[i-1],
              color='b', alpha=0.6)

# 시작점과 끝점 강조
ax.scatter(x.iloc[0], y.iloc[0], z.iloc[0], color='g', label='Start Point')  # 시작점
ax.scatter(x.iloc[-1], y.iloc[-1], z.iloc[-1], color='r', label='End Point')  # 끝점

# 축 레이블 설정
ax.set_xlabel('X-axis (vx_sum)')
ax.set_ylabel('Y-axis (vy_sum)')
ax.set_zlabel('Z-axis (vz_sum)')

# 제목과 범례 추가
plt.title('3D VCG Geometry with Vectors')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# X-Y 평면 투영
plt.figure(figsize=(6, 6))
plt.plot(result1['vx_sum'], result1['vy_sum'], color='b', label='X-Y Projection')
plt.xlabel('X-axis (vx_sum)')
plt.ylabel('Y-axis (vy_sum)')
plt.title('VCG 2D Projection on X-Y Plane')
plt.legend()
plt.grid()
plt.show()

# Y-Z 평면 투영
plt.figure(figsize=(6, 6))
plt.plot(result1['vy_sum'], result1['vz_sum'], color='g', label='Y-Z Projection')
plt.xlabel('Y-axis (vy_sum)')
plt.ylabel('Z-axis (vz_sum)')
plt.title('VCG 2D Projection on Y-Z Plane')
plt.legend()
plt.grid()
plt.show()

# X-Z 평면 투영
plt.figure(figsize=(6, 6))
plt.plot(result1['vx_sum'], result1['vz_sum'], color='r', label='X-Z Projection')
plt.xlabel('X-axis (vx_sum)')
plt.ylabel('Z-axis (vz_sum)')
plt.title('VCG 2D Projection on X-Z Plane')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np

# 벡터 필드 시각화
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 데이터 간격 설정 (너무 많은 벡터를 표시하지 않도록 샘플링)
step = 10  # 10개 간격으로 데이터 선택
x_sample = result1['vx_sum'][::step]
y_sample = result1['vy_sum'][::step]
z_sample = result1['vz_sum'][::step]

# 벡터 시작점과 방향 계산
u = np.diff(x_sample, prepend=x_sample.iloc[0])  # X 방향 벡터
v = np.diff(y_sample, prepend=y_sample.iloc[0])  # Y 방향 벡터
w = np.diff(z_sample, prepend=z_sample.iloc[0])  # Z 방향 벡터

# 벡터 필드 그리기
ax.quiver(x_sample, y_sample, z_sample, u, v, w, length=0.2, normalize=True, color='b')

# 축 설정
ax.set_xlabel('X-axis (vx_sum)')
ax.set_ylabel('Y-axis (vy_sum)')
ax.set_zlabel('Z-axis (vz_sum)')
plt.title('VCG Vector Field')
plt.show()

# %%
import plotly.graph_objects as go

# 3D 궤적 생성
fig = go.Figure()

fig.add_trace(go.Scatter3d(
    x=result1['vx_sum'],
    y=result1['vy_sum'],
    z=result1['vz_sum'],
    mode='lines+markers',
    marker=dict(size=4, color=np.arange(len(result1)), colorscale='Viridis', opacity=0.8),
    line=dict(color='blue', width=2)
))

# 레이아웃 설정
fig.update_layout(
    scene=dict(
        xaxis_title='X-axis (vx_sum)',
        yaxis_title='Y-axis (vy_sum)',
        zaxis_title='Z-axis (vz_sum)'
    ),
    title="Interactive 3D VCG Visualization"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for key in Set:
  plt.plot(Set[key]['vx'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vx]")
plt.plot(result1['vx_sum'], color='r',label="Average VCG[vx]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
for key in Set:
  plt.plot(Set[key]['vy'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vy]")
plt.plot(result1['vy_sum'], color='r',label="Average VCG[vy]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
for key in Set:
  plt.plot(Set[key]['vz'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vz]")
plt.plot(result1['vz_sum'], color='r',label="Average VCG[vz]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation


# x, y, z 데이터 추출
x = result1['vx_sum']
y = result1['vy_sum']
z = result1['vz_sum']

# 3D 플롯 초기화
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 축 설정
ax.set_xlim(min(x), max(x))
ax.set_ylim(min(y), max(y))
ax.set_zlim(min(z), max(z))
ax.set_xlabel("vx_mean (X-axis)")
ax.set_ylabel("vy_mean (Y-axis)")
ax.set_zlabel("vz_mean (Z-axis)")
ax.set_title("3D Trajectory Animation with Rotation")

# 궤적 초기화
line, = ax.plot([], [], [], lw=2, color='blue')  # 궤적 선

# 애니메이션 업데이트 함수
def update(num):
    # 궤적 업데이트
    line.set_data(x[:num], y[:num])  # x, y 데이터 업데이트
    line.set_3d_properties(z[:num])  # z 데이터 업데이트

    # 회전 추가
    ax.view_init(elev=30, azim=num/4)  # elev는 위아래, azim은 좌우 회전

    return line,

# 애니메이션 생성
ani1 = FuncAnimation(fig, update, frames=len(x), interval=30, blit=True)

# 애니메이션 표시
plt.show()

# %%
ani1.save('3d_animation.gif', writer='pillow', fps=20)

# %% [markdown]
# #Dipole Model

# %%
cut_155=pd.read_csv('/content/cut_155.csv')
pr_start = 420
pr_end = 460
i_155 = cut_155['i'] - np.mean(cut_155['i'][pr_start:pr_end])
ii_155 = cut_155['ii'] - np.mean(cut_155['ii'][pr_start:pr_end])
iii_155 = cut_155['iii'] - np.mean(cut_155['iii'][pr_start:pr_end])
avr_155 = cut_155['avr'] - np.mean(cut_155['avr'][pr_start:pr_end])
avl_155 = cut_155['avl'] - np.mean(cut_155['avl'][pr_start:pr_end])
avf_155 = cut_155['avf'] - np.mean(cut_155['avf'][pr_start:pr_end])
v1_155 = cut_155['v1'] - np.mean(cut_155['v1'][pr_start:pr_end])
v2_155 = cut_155['v2'] - np.mean(cut_155['v2'][pr_start:pr_end])
v3_155 = cut_155['v3'] - np.mean(cut_155['v3'][pr_start:pr_end])
v4_155 = cut_155['v4'] - np.mean(cut_155['v4'][pr_start:pr_end])
v5_155 = cut_155['v5'] - np.mean(cut_155['v5'][pr_start:pr_end])
v6_155 = cut_155['v6'] - np.mean(cut_155['v6'][pr_start:pr_end])
vx_155 = cut_155['vx'] - np.mean(cut_155['vx'][pr_start:pr_end])
vy_155 = cut_155['vy'] - np.mean(cut_155['vy'][pr_start:pr_end])
vz_155 = cut_155['vz'] - np.mean(cut_155['vz'][pr_start:pr_end])

# 배열 데이터를 DataFrame으로 저장
patient_155 = pd.DataFrame({
    'i': i_155,
    'ii': ii_155,
    'iii': iii_155,
    'avr': avr_155,
    'avl': avl_155,
    'avf': avf_155,
    'v1': v1_155,
    'v2': v2_155,
    'v3': v3_155,
    'v4': v4_155,
    'v5': v5_155,
    'v6': v6_155,
    'vx': vx_155,
    'vy': vy_155,
    'vz': vz_155
})

sos1 = signal.butter(2, 0.1, 'high', fs=1000, output='sos')
patient_155=signal.sosfilt(sos1, patient_155)
patient_155
# Out:
# array([[ 0.16216544,  0.25691667,  0.0944729 , ...,  0.2241979 ,
#          0.18688956, -0.01450029],
#        [ 0.15916677,  0.25641956,  0.0969749 , ...,  0.22071276,
#          0.18990464, -0.01548611],
#        [ 0.16166566,  0.25641734,  0.09447379, ...,  0.22022674,
#          0.18642038, -0.01346971],
#        ...,
#        [ 0.01173229, -0.00033528, -0.01211725, ...,  0.03443411,
#         -0.00120577, -0.02000896],
#        [ 0.01323162,  0.00116272, -0.01211992, ...,  0.0324319 ,
#         -0.00220664, -0.02000939],
#        [ 0.01073273, -0.00033439, -0.01161659, ...,  0.0329401 ,
#         -0.00519734, -0.01949898]])

# %%
plt.plot(patient_155)

# %%
#대표 Data 뽑기 위한 Data Plot 확인

plt.figure(figsize=(6, 6))
plt.plot(Set[7])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.title('Set[7]/Patient 150')
plt.grid()
plt.show()

# Y-Z 평면 투영
plt.figure(figsize=(6, 6))
plt.plot(Set[8])
plt.xlabel('Samples')
plt.ylabel('Amplitude')
plt.title('Set[8]/Patient 155')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Torso 파라미터
height = 20  # Torso의 높이 (cm)
radius = 10  # Torso의 반지름 (cm)

# 원통 좌표 생성
z = np.linspace(0, height, 100)  # 높이 방향
theta = np.linspace(0, 2 * np.pi, 100)  # 원 둘레 방향
theta_grid, z_grid = np.meshgrid(theta, z)

# 원통의 x, y 좌표
x = radius * np.cos(theta_grid)
y = radius * np.sin(theta_grid)

# 심장의 Dipole 위치
dipole_x = 0  # 심장은 원통 중심에 위치
dipole_y = 0
dipole_z = height / 2  # 높이의 중간 위치

# Dipole 방향 벡터
dipole_dx = 3  # x 방향 Dipole 크기
dipole_dy = 0  # y 방향 Dipole 크기
dipole_dz = 5  # z 방향 Dipole 크기

# 3D 플롯 생성
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Torso 원통 그리기
ax.plot_surface(x, y, z_grid, alpha=0.5, rstride=10, cstride=10, color='cyan', edgecolor='gray')

# 심장의 Dipole 표시
ax.quiver(dipole_x, dipole_y, dipole_z, dipole_dx, dipole_dy, dipole_dz, color='red', linewidth=2, label="Heart Dipole")

# 축 설정
ax.set_xlabel('X-axis (cm)')
ax.set_ylabel('Y-axis (cm)')
ax.set_zlabel('Z-axis (cm)')
ax.set_title('Cylindrical Torso Model with Heart Dipole')
ax.legend()

# 그래프 표시
plt.show()

# %%
import numpy as np

# 12-리드 ECG 데이터 (mV 단위, 예제 데이터)
lead_I = 0.5
lead_II = 0.8
lead_III = lead_II - lead_I  # Einthoven 법칙
aVR = -0.3
aVL = 0.4
aVF = 0.6
V1, V2, V3, V4, V5, V6 = -0.2, 0.1, 0.3, 0.5, 0.7, 0.9

# 리드 방향 벡터 (x, y, z)
lead_vectors = {
    "I": np.array([1, 0, 0]),
    "II": np.array([0.5, np.sqrt(3)/2, 0]),
    "III": np.array([-0.5, np.sqrt(3)/2, 0]),
    "aVR": np.array([-1/2, -np.sqrt(3)/2, 0]),
    "aVL": np.array([1/2, -np.sqrt(3)/2, 0]),
    "aVF": np.array([0, 1, 0]),
    "V1": np.array([0, 0, -1]),
    "V2": np.array([0, 0, -1]),
    "V3": np.array([0, 0, -1]),
    "V4": np.array([0, 0, -1]),
    "V5": np.array([0, 0, -1]),
    "V6": np.array([0, 0, -1]),
}

# 리드 전위 데이터
lead_potentials = {
    "I": lead_I,
    "II": lead_II,
    "III": lead_III,
    "aVR": aVR,
    "aVL": aVL,
    "aVF": aVF,
    "V1": V1,
    "V2": V2,
    "V3": V3,
    "V4": V4,
    "V5": V5,
    "V6": V6,
}

# Heart Dipole 계산
dipole = np.array([0.0, 0.0, 0.0])

for lead, potential in lead_potentials.items():
    dipole += potential * lead_vectors[lead]

# Dipole 크기와 방향
dipole_magnitude = np.linalg.norm(dipole)
dipole_direction = dipole / dipole_magnitude

print("Heart Dipole Vector:", dipole)
print("Dipole Magnitude:", dipole_magnitude)
print("Dipole Direction:", dipole_direction)
# Out:
# Heart Dipole Vector: [ 1.1        1.4660254 -2.3      ]
# Dipole Magnitude: 2.9409574095082243
# Dipole Direction: [ 0.37402786  0.49848576 -0.78205825]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# CSV 파일 로드
file_path = "cut_155.csv"  # 업로드된 파일 경로
data = pd.read_csv(file_path)

# 주요 열 추출
leads = ["i", "ii", "iii", "avr", "avl", "avf"]
vectors = ["vx", "vy", "vz"]

# Dipole 계산
data["px"] = data["vx"]  # x축 성분
data["py"] = data["vy"]  # y축 성분
data["pz"] = data["vz"]  # z축 성분

# Dipole 크기 계산
data["magnitude"] = np.sqrt(data["px"]**2 + data["py"]**2 + data["pz"]**2)

# 3D 시각화
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Dipole 벡터 플롯
ax.quiver(
    np.zeros(len(data)),
    np.zeros(len(data)),
    np.zeros(len(data)),
    data["px"],
    data["py"],
    data["pz"],
    length=0.1,
    normalize=True,
    color="blue",
)

# 축 라벨 설정
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.set_title("3D Dipole Model")

# 그래프 표시
plt.show()

# Dipole 크기 시각화
plt.figure(figsize=(12, 6))
plt.plot(data["magnitude"], label="Dipole Magnitude", color="red")
plt.xlabel("Time")
plt.ylabel("Magnitude")
plt.title("Dipole Magnitude Over Time")
plt.legend()
plt.grid()
plt.show()

# %%
cut_155=pd.read_csv('/content/cut_155.csv')
# Frank 리드 추출
x_lead = cut_155['vx']  # X 리드
y_lead = cut_155['vy']  # Y 리드
z_lead = cut_155['vz']  # Z 리드

# 쌍극자 모멘트 계산
import numpy as np
dipole_moment = np.sqrt(x_lead**2 + y_lead**2 + z_lead**2)

dipole_moment
# Out:
# 0      0.420580
# 1      0.416764
# 2      0.416706
# 3      0.413855
# 4      0.412181
#          ...
# 995    0.317684
# 996    0.320511
# 997    0.324170
# 998    0.323489
# 999    0.326015
# Length: 1000, dtype: float64

# %%
import matplotlib.pyplot as plt

# 시간에 따른 쌍극자 모멘트 시각화
plt.plot(dipole_moment)
plt.title('Cardiac Dipole Moment Over Time')
plt.xlabel('Time (ms)')
plt.ylabel('Dipole Moment (magnitude)')
plt.show()

# %%
lead_vector = np.array([0.5, 0.3, 0.2])
dipole_vector = np.vstack((x_lead, y_lead, z_lead)).T
potential = np.dot(dipole_vector, lead_vector)

# %%
import matplotlib.pyplot as plt

# 쌍극자 크기 계산
dipole_magnitude = np.linalg.norm(dipole_vector, axis=1)

# 시각화
plt.plot(dipole_magnitude)
plt.title('Dipole Magnitude Over Time')
plt.xlabel('Time (ms)')
plt.ylabel('Dipole Magnitude')
plt.show()

# %%
plt.plot(potential)
plt.title('Potential at Point P Over Time')
plt.xlabel('Time (ms)')
plt.ylabel('Potential (Φ_P)')
plt.show()

# %%
electrical_axis = np.arctan2(lead_vector[1], lead_vector[0]) * (180 / np.pi)
print(f"Electrical Axis: {electrical_axis:.2f} degrees")
# Out:
# Electrical Axis: 30.96 degrees

# %%
id: cylinder_torso_points
name: Cylinder Torso Point Calculation
type: code.python
content: |-
  import numpy as np
  import matplotlib.pyplot as plt

  # Parameters
  R = 0.2  # Radius of the circle
  delta_h = 0.1  # Height increment
  angles = [np.pi / 6, 2 * np.pi / 6]  # Angles for P1, P2, P4, P5

  # Calculate points
  P1 = (-R * np.cos(angles[0]), -R * np.sin(angles[0]), 0)
  P2 = (-R * np.cos(angles[1]), -R * np.sin(angles[1]), -delta_h)
  P3 = (0, -R, -2 * delta_h)
  P4 = (R * np.cos(angles[1]), -R * np.sin(angles[1]), -3 * delta_h)
  P5 = (R * np.cos(angles[0]), -R * np.sin(angles[0]), -4 * delta_h)

  # Print calculated points
  print("P1:", P1)
  print("P2:", P2)
  print("P3:", P3)
  print("P4:", P4)
  print("P5:", P5)

  # Visualization
  fig = plt.figure(figsize=(8, 6))
  ax = fig.add_subplot(111, projection='3d')

  # Plot points
  points = np.array([P1, P2, P3, P4, P5])
  ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='red', s=50, label='Points')

  # Connect points with lines
  for i in range(len(points) - 1):
      ax.plot([points[i, 0], points[i + 1, 0]],
              [points[i, 1], points[i + 1, 1]],
              [points[i, 2], points[i + 1, 2]], color='blue')

  # Plot settings
  ax.set_xlabel("X-axis")
  ax.set_ylabel("Y-axis")
  ax.set_zlabel("Z-axis")
  ax.set_title("Cylinder Torso Model")
  ax.legend()
  plt.show()
# Out:
#   File "<ipython-input-1-eb93c85307a5>", line 2
#     name: Cylinder Torso Point Calculation
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd

# 1. 샘플 번호 및 Vx, Vy, Vz 데이터 정의 (가상의 데이터)
samples = np.arange(1, 1001)  # 샘플 번호: 1, 2, 3, 4
Vx = Set[8]['vx']  # Vx 성분
Vy = Set[8]['vy']  # Vy 성분
Vz = Set[8]['vz']  # Vz 성분

# 2. Dipole Vector 계산
dipole_vectors = np.array([Vx, Vy, Vz]).T  # 각 샘플별 (Vx, Vy, Vz) 벡터
magnitudes = np.linalg.norm(dipole_vectors, axis=1)  # 벡터 크기 계산

# 3. 결과를 데이터프레임으로 정리
results = pd.DataFrame({
    "Sample": samples,
    "Vx": Vx,
    "Vy": Vy,
    "Vz": Vz,
    "Dipole Vector": [tuple(vec) for vec in dipole_vectors],
    "Magnitude": magnitudes
})

# 4. 결과 출력
print(results)
# Out:
#      Sample        Vx        Vy        Vz  \
# 0         1  0.225587  0.188278 -0.013112
# 1         2  0.222089  0.191280 -0.014111
# 2         3  0.221589  0.187782 -0.012109
# 3         4  0.218590  0.186785 -0.011605
# 4         5  0.216591  0.185787 -0.008104
# ..      ...       ...       ...       ...
# 995     996  0.029674  0.003035 -0.023269
# 996     997  0.031673  0.001034 -0.023269
# 997     998  0.034672 -0.000968 -0.019771
# 998     999  0.032673 -0.001966 -0.019769
# 999    1000  0.033173 -0.004965 -0.019267
#
#                                          Dipole Vector  Magnitude
# 0    (0.22558725195685342, 0.18827829095883686, -0....   0.294126
# 1    (0.2220888066204968, 0.1912800670264143, -0.01...   0.293446
# 2    (0.221589028715303, 0.18778206578097406, -0.01...   0.290707
# 3    (0.21859036128414017, 0.1867851745160847, -0.0...   0.287759
# 4    (0.2165912496633649, 0.18578739506936248, -0.0...   0.285472
# ...

# %%
plt.plot(samples, magnitudes)
plt.title("Dipole Vector Magnitude Across Samples")
plt.xlabel("Sample Number")
plt.ylabel("Magnitude")
plt.grid()
plt.show()

# %%
import plotly.graph_objects as go
import numpy as np

# Helix equation
t = np.linspace(0, 20, 100)
fig = go.Figure(data=[go.Scatter3d(
    x=Set[32]['vx'],
    y=Set[32]['vy'],
    z=Set[32]['vz'],
    mode='markers',
    marker=dict(
        size=5,
        opacity=0.8
    )
)])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-c8327838a30b> in <cell line: 0>()
#       5 t = np.linspace(0, 20, 100)
#       6 fig = go.Figure(data=[go.Scatter3d(
# ----> 7     x=Set[32]['vx'],
#       8     y=Set[32]['vy'],
#       9     z=Set[32]['vz'],
#
# KeyError: 32

# %%
# 벡터 방향 시각화
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x=Set[29]['vx']
y=Set[29]['vy']
z=Set[29]['vz']

# 각 점에서 벡터를 화살표로 그리기
for i in range(1, len(x)):
    ax.quiver(x.iloc[i-1], y.iloc[i-1], z.iloc[i-1],
              x.iloc[i] - x.iloc[i-1],
              y.iloc[i] - y.iloc[i-1],
              z.iloc[i] - z.iloc[i-1],
              color='b', alpha=0.6)

# 시작점과 끝점 강조
ax.scatter(x.iloc[0], y.iloc[0], z.iloc[0], color='g', label='Start Point')  # 시작점
ax.scatter(x.iloc[-1], y.iloc[-1], z.iloc[-1], color='r', label='End Point')  # 끝점

# 축 레이블 설정
ax.set_xlabel('X-axis (vx_sum)')
ax.set_ylabel('Y-axis (vy_sum)')
ax.set_zlabel('Z-axis (vz_sum)')

# 제목과 범례 추가
plt.title('3D VCG Geometry with Vectors')
plt.legend()
plt.show()

# %% [markdown]
# #Dot Product

# %%
vectors = result1.to_numpy()
dot_p = pd.DataFrame(columns=['L1', 'L2', 'L3'])

for i in range(1000):
  v1 = result1.iloc[i]['vx_sum']
  v2 = result1.iloc[i]['vy_sum']
  v3 = result1.iloc[i]['vz_sum']
  L1= np.dot(v1, v3)
  L2= np.dot(v2, v3)
  L3= np.dot(v1, v2)

  dot_p.loc[i] = [L1, L2, L3] # vx,vz -> Lead1 / vy,vz -> Lead2 / vx,vy -> Lead3
  vx_sum=0
  vy_sum=0
  vz_sum=0

# %%
plt.plot(dot_p) #Green Lead1 / Orange Lead2 / Blue Lead3

# %%
dot_p.to_csv('dot_p.csv',index=False)

# %%
vectors2 = D1[5].to_numpy()
dot_p2 = pd.DataFrame(columns=['L12', 'L22', 'L32'])

for i in range(1000):
  v12 = D1[5].iloc[i]['vx']
  v22 = D1[5].iloc[i]['vy']
  v32 = D1[5].iloc[i]['vz']
  L12= np.dot(v12, v32)
  L22= np.dot(v22, v32)
  L32= np.dot(v12, v22)

  dot_p2.loc[i] = [L12, L22, L32] # vx,vz -> Lead1 / vy,vz -> Lead2 / vx,vy -> Lead3
  vx=0
  vy=0
  vz=0

# %%
plt.plot(D1[1])

# %% [markdown]
# #Offset 제거 x

# %%
# 결과를 저장할 빈 DataFrame 생성
result11 = pd.DataFrame(columns=['vx_sum', 'vy_sum', 'vz_sum'])

# 0부터 1000번째 행까지 반복
for i in range(1000):
    # 각 i번째 행에서 vx, vy, vz 값을 합산
    vx_sum = sum(D1[key].iloc[i]['vx'] for key in D1.keys())
    vx_sum=vx_sum/52
    vy_sum = sum(D1[key].iloc[i]['vy'] for key in D1.keys())
    vy_sum=vy_sum/52
    vz_sum = sum(D1[key].iloc[i]['vz'] for key in D1.keys())
    vz_sum=vz_sum/52

    # 결과를 DataFrame의 새로운 행으로 추가
    result11.loc[i] = [vx_sum, vy_sum, vz_sum]
    vx_sum=0
    vy_sum=0
    vz_sum=0


# 결과 확인 (예: 첫 번째 5개의 결과 출력)
print(result11.head())
# Out:
#      vx_sum    vy_sum    vz_sum
# 0 -0.069508 -0.505050  0.054765
# 1 -0.069892 -0.504589  0.054957
# 2 -0.070363 -0.504636  0.055189
# 3 -0.070574 -0.505309  0.055362
# 4 -0.070719 -0.504598  0.055593

# %%
import plotly.graph_objects as go
import numpy as np

# Helix equation
t = np.linspace(0, 20, 100)
fig = go.Figure(data=[go.Scatter3d(
    x=result11['vx_sum'],
    y=result11['vy_sum'],
    z=result11['vz_sum'],
    mode='markers',
    marker=dict(
        size=5,
        opacity=0.8
    )
)])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation


# x, y, z 데이터 추출
x = result11['vx_sum']
y = result11['vy_sum']
z = result11['vz_sum']

# 3D 플롯 초기화
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 축 설정
ax.set_xlim(min(x), max(x))
ax.set_ylim(min(y), max(y))
ax.set_zlim(min(z), max(z))
ax.set_xlabel("vx_mean (X-axis)")
ax.set_ylabel("vy_mean (Y-axis)")
ax.set_zlabel("vz_mean (Z-axis)")
ax.set_title("3D Trajectory Animation with Rotation")

# 궤적 초기화
line, = ax.plot([], [], [], lw=2, color='blue')  # 궤적 선

# 애니메이션 업데이트 함수
def update(num):
    # 궤적 업데이트
    line.set_data(x[:num], y[:num])  # x, y 데이터 업데이트
    line.set_3d_properties(z[:num])  # z 데이터 업데이트

    # 회전 추가
    ax.view_init(elev=30, azim=num/4)  # elev는 위아래, azim은 좌우 회전

    return line,

# 애니메이션 생성
ani11 = FuncAnimation(fig, update, frames=len(x), interval=30, blit=True)

# 애니메이션 표시
plt.show()

# %%
ani11.save('3d_animation.gif', writer='pillow', fps=20)

# %%
for key in D1:
  plt.plot(D1[key]['vx'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vx]")
plt.plot(result11['vx_sum'], color='r',label="Average VCG[vx]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
for key in D1:
  plt.plot(D1[key]['vy'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vy]")
plt.plot(result11['vy_sum'], color='r',label="Average VCG[vy]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %%
for key in D1:
  plt.plot(D1[key]['vz'], alpha=0.3,color='b')
plt.plot([], color='b', alpha=0.3, label="Healthy VCG[vz]")
plt.plot(result11['vz_sum'], color='r',label="Average VCG[vz]")
plt.grid(True)
plt.title("Average VCG")
plt.xlabel("samples")
plt.ylabel("Amplitude")
plt.legend()
plt.show()

# %% [markdown]
# #Myocardial infarction(심근경색)

# %%
Data2= {
    1:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient001/s0016lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    2:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient002/s0015lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    3:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient003/s0017lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    4:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient004/s0020are.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    5:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient005/s0101lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    6:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient006/s0064lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    7:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient007/s0078lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    8:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient008/s0037lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    9:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient009/s0035_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    10:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient010/s0061lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    11:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient011/s0039lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    12:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient012/s0050lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    13:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient013/s0072lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    14:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient014/s0071lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    15:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient015/s0152lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    16:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient016/s0076lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    17:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient017/s0075lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    18:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient018/s0054lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    19:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient019/s0077lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    20:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient020/s0079lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    21:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient021/s0073lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    22:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient022/s0074lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    23:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient023/s0080lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    24:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient024/s0083lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    25:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient025/s0150lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    26:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient026/s0088lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    27:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient027/s0151lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    28:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient028/s0108lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    29:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient029/s0122lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    30:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient030/s0107lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    31:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient031/s0127lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    32:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient032/s0165lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    33:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient033/s0113lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    34:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient034/s0158lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    35:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient035/s0110lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    36:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient036/s0126lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    37:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient037/s0120lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    38:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient038/s0128lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    39:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient039/s0129lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    40:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient040/s0133lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    41:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient041/s0136lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    42:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient042/s0140lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    43:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient043/s0278lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    44:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient044/s0159lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    45:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient045/s0155lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    46:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient046/s0161lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    47:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient047/s0163lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    48:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient048/s0277lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    49:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient049/s0314lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    50:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient050/s0215lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    51:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient051/s0179lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    52:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient052/s0190lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    53:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient053/s0191lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    54:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient054/s0197lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    55:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient055/s0194lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    56:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient056/s0196lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    57:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient057/s0198lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    58:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient058/s0216lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    59:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient059/s0208lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    60:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient060/s0209lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    61:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient061/s0210lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    62:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient062/s0212lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    63:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient063/s0214lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    64:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient064/s0220lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    65:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient065/s0282lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    66:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient066/s0231lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    67:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient067/s0283lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    68:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient068/s0228lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    69:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient069/s0234lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    70:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient070/s0235lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    71:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient071/s0236lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    72:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient072/s0244lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    73:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient073/s0252lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    74:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient074/s0406lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    75:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient075/s0242lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    76:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient076/s0319lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    77:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient077/s0258lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    78:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient078/s0262lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    79:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient079/s0269lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    80:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient080/s0260lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    81:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient081/s0346lre.csv',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    82:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient082/s0279lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    83:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient083/s0286lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    84:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient084/s0313lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    85:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient085/s0298lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    86:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient086/s0316lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    87:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient087/s0326lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    88:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient088/s0413lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    89:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient089/s0355lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    90:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient090/s0356lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    91:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient091/s0361lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    92:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient092/s0411lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    93:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient093/s0396lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    94:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient094/s0370lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    95:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient095/s0373lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    96:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient096/s0395lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    97:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient097/s0380lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    98:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient098/s0409lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    99:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient099/s0397lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    100:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient100/s0407lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    101:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient101/s0414lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    102:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient102/s0416lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    103:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient103/s0332lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    104:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient108/s0013_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    105:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient111/s0203_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    106:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient120/s0331lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    107:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient128/s0182_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    108:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient135/s0334lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    109:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient138/s0005_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    110:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient139/s0223_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    111:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient140/s0019_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    112:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient141/s0307lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    113:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient142/s0351lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    114:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient145/s0201_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    115:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient148/s0335lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    116:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient149/s0202are.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    117:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient152/s0004_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    118:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient158/s0294lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    119:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient160/s0222_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    120:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient163/s0034_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    121:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient183/s0175_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    122:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient189/s0309lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    123:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient193/s0008_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    124:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient195/s0337lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    125:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient197/s0350lre.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    126:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient205/s0426_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    127:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient207/s0428_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    128:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient211/s0433_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    129:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient223/s0446_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    130:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient226/s0449_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    131:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient230/s0454_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    132:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient231/s0455_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    133:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient259/s0495_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    134:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient261/s0497_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    135:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient265/s0501_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    136:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient268/s0505_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    137:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient270/s0507_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    138:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient273/s0511_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    139:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient274/s0512_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    140:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient280/s0535_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    141:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient282/s0539_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    142:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient283/s0542_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    143:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient287/s0548_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    144:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient290/s0553_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    145:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient291/s0554_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    146:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient292/s0556_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    147:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient293/s0558_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:],
    148:
    pd.read_csv('/content/drive/MyDrive/Myocardial infarction/patient294/s0559_re.csv',engine='python',header=0, names = ['i','ii','iii','avr','avl','avf','v1','v2','v3','v4','v5','v6','vx','vy','vz']).iloc[:3000,:]}

# %%
data2={}

def data2_set():
  for i in range (1,149):
    data2[i]= pd.DataFrame(Data2[i],columns = ['vx','vy','vz'], dtype = float).reset_index(drop=True)

data2_set()

# %%
filter2={}

def HP_filter2():
  sos1 = signal.butter(2, 0.1, 'high', fs=1000, output='sos')
  for a in range(1,149):
    filter2[a]= pd.DataFrame(signal.sosfilt(sos1, data2[a]),columns = ['vx','vy','vz'], dtype = float)

HP_filter2()

# %%
plt.plot(filter2[1]) #vx,vy,vz의 피크 지점 동일

# %%
plt.plot(filter2[47]['vx'])

# %%
ecg_signal = np.array(filter2[1]['vx']) # 'ECG' 열의 데이터를 가져옴 하나만 측정
fs = 1000  # 샘플 레이트

# %%
from wfdb import processing
# XQRS 객체 생성 및 QRS 탐지
def detect():
  ecg_signal = {}
  for i in range (1,149):
    ecg_signal[i] = np.array(filter2[i]['vx'])
    xqrs = processing.XQRS(sig=ecg_signal[i], fs=fs)
    xqrs.detect()
    print("QRS 피크 위치:",[i],xqrs.qrs_inds)

detect()
# Out:
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [1] []
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [2] []
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [3] []
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [4] []
# Learning initial signal parameters...
# Failed to find 8 beats during learning.
# Initializing using default parameters
# Running QRS detection...
# QRS detection complete.
# QRS 피크 위치: [5] []
# ...

# %%
import matplotlib.pyplot as plt

# ECG 신호 리스트와 XQRS 객체 리스트
ecg_signals = [ecg_signal1, ecg_signal2, ecg_signal3]
xqrs_objects = [xqrs1, xqrs2, xqrs3]

# 서브플롯 생성
num_signals = len(ecg_signals)  # 신호 개수
plt.figure(figsize=(12, 4 * num_signals))  # 그래프 크기 설정

for i, (ecg_signal, xqrs) in enumerate(zip(ecg_signals, xqrs_objects)):
    # 각 신호에 대해 subplot 생성
    plt.subplot(num_signals, 1, i + 1)  # (전체 행, 전체 열, 현재 위치)
    plt.plot(ecg_signal, label=f'ECG Signal {i + 1}')  # ECG 신호
    plt.plot(xqrs.qrs_inds, ecg_signal[xqrs.qrs_inds], 'ro', label='QRS Peaks')  # QRS 피크
    plt.title(f'ECG Signal {i + 1} with QRS Peaks')
    plt.xlabel('Sample Index')
    plt.ylabel('Amplitude')
    plt.legend()  # 범례 추가
    plt.grid(True)  # 격자 추가

# 그래프 간 간격 조정
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-50-12452791d551> in <cell line: 0>()
#      13     plt.subplot(num_signals, 1, i + 1)  # (전체 행, 전체 열, 현재 위치)
#      14     plt.plot(ecg_signal, label=f'ECG Signal {i + 1}')  # ECG 신호
# ---> 15     plt.plot(xqrs.qrs_inds, ecg_signal[xqrs.qrs_inds], 'ro', label='QRS Peaks')  # QRS 피크
#      16     plt.title(f'ECG Signal {i + 1} with QRS Peaks')
#      17     plt.xlabel('Sample Index')
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
D2={
    1:filter2[11].iloc[473:1473,:].reset_index(drop=True),
    2:filter2[17].iloc[885:1885,:].reset_index(drop=True),
    3:filter2[18].iloc[435:1435,:].reset_index(drop=True),
    4:filter2[21].iloc[613:1613,:].reset_index(drop=True),
    5:filter2[22].iloc[861:1861,:].reset_index(drop=True),
    6:filter2[23].iloc[1169:2169,:].reset_index(drop=True),
    7:filter2[50].iloc[1055:2055,:].reset_index(drop=True),
    8:filter2[51].iloc[731:1731,:].reset_index(drop=True),
    9:filter2[71].iloc[1826:2826,:].reset_index(drop=True),
    10:filter2[74].iloc[1387:2387,:].reset_index(drop=True),
    11:filter2[75].iloc[1095:2095,:].reset_index(drop=True),
    12:filter2[80].iloc[718:1718,:].reset_index(drop=True),
    13:filter2[81].iloc[662:1662,:].reset_index(drop=True),
    14:filter2[86].iloc[939:1939,:].reset_index(drop=True),
    15:filter2[88].iloc[484:1484,:].reset_index(drop=True),
    16:filter2[89].iloc[870:1870,:].reset_index(drop=True),
    17:filter2[107].iloc[724:1724,:].reset_index(drop=True),
    18:filter2[117].iloc[1328:2328,:].reset_index(drop=True),
    19:filter2[119].iloc[908:1908,:].reset_index(drop=True),
    20:filter2[124].iloc[586:1586,:].reset_index(drop=True),
    21:filter2[126].iloc[1104:2104,:].reset_index(drop=True),
    22:filter2[130].iloc[1133:2133,:].reset_index(drop=True),
    23:filter2[138].iloc[1223:2223,:].reset_index(drop=True),
    24:filter2[142].iloc[928:1928,:].reset_index(drop=True),
    25:filter2[143].iloc[933:1933,:].reset_index(drop=True),
    26:filter2[147].iloc[:1000,:].reset_index(drop=True),
}

# %%
# 결과를 저장할 빈 DataFrame 생성
result2 = pd.DataFrame(columns=['vx_sum', 'vy_sum', 'vz_sum'])

# 0부터 1000번째 행까지 반복
for i in range(1000):
    # 각 i번째 행에서 vx, vy, vz 값을 합산
    vx_sum = sum(D2[key].iloc[i]['vx'] for key in D2.keys())
    vx_sum=vx_sum/52
    vy_sum = sum(D2[key].iloc[i]['vy'] for key in D2.keys())
    vy_sum=vy_sum/52
    vz_sum = sum(D2[key].iloc[i]['vz'] for key in D2.keys())
    vz_sum=vz_sum/52

    # 결과를 DataFrame의 새로운 행으로 추가
    result2.loc[i] = [vx_sum, vy_sum, vz_sum]
    vx_sum=0
    vy_sum=0
    vz_sum=0


# 결과 확인 (예: 첫 번째 5개의 결과 출력)
print(result2.head())
# Out:
#      vx_sum    vy_sum    vz_sum
# 0 -0.057590 -0.016518  0.050024
# 1 -0.056946 -0.016663  0.050207
# 2 -0.056571 -0.016577  0.050100
# 3 -0.056840 -0.017009  0.050024
# 4 -0.056677 -0.017134  0.050668

# %%
import plotly.graph_objects as go
import numpy as np

# Helix equation
t = np.linspace(0, 20, 100)
fig = go.Figure(data=[go.Scatter3d(
    x=result2['vx_sum'],
    y=result2['vy_sum'],
    z=result2['vz_sum'],
    mode='markers',
    marker=dict(
        size=5,
        opacity=0.8
    )
)])

# tight layout
fig.update_layout(margin=dict(l=0, r=0, b=0, t=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation


# x, y, z 데이터 추출
x = result2['vx_sum']
y = result2['vy_sum']
z = result2['vz_sum']

# 3D 플롯 초기화
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# 축 설정
ax.set_xlim(min(x), max(x))
ax.set_ylim(min(y), max(y))
ax.set_zlim(min(z), max(z))
ax.set_xlabel("vx_mean (X-axis)")
ax.set_ylabel("vy_mean (Y-axis)")
ax.set_zlabel("vz_mean (Z-axis)")
ax.set_title("3D Trajectory Animation with Rotation")

# 궤적 초기화
line, = ax.plot([], [], [], lw=2, color='blue')  # 궤적 선

# 애니메이션 업데이트 함수
def update(num):
    # 궤적 업데이트
    line.set_data(x[:num], y[:num])  # x, y 데이터 업데이트
    line.set_3d_properties(z[:num])  # z 데이터 업데이트

    # 회전 추가
    ax.view_init(elev=30, azim=num)  # elev는 위아래, azim은 좌우 회전

    return line,

# 애니메이션 생성
ani2 = FuncAnimation(fig, update, frames=len(x), interval=30, blit=True)

# 애니메이션 표시
plt.show()

# %%
ani2.save('3d_animation.gif', writer='pillow', fps=20)
